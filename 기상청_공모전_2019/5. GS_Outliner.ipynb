# %%
# 윈도우
# %matplotlib notebook
import warnings
import missingno as msno
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
from matplotlib.font_manager import fontManager
import squarify
import matplotlib

for font in fontManager.ttflist:
    if 'Na' in font.name:
        print(font.name)
        
warnings.filterwarnings(action='ignore')
plt.rc('font', family='08SeoulNamsan')
plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.color'] = 'r'

# %%
#맥
import pandas as pd
import warnings
import missingno as msno
import numpy as np
import os
import matplotlib
from scipy import stats
from matplotlib.image import imread
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import squarify 
from matplotlib import rc
rc('font', family = 'AppleGothic')
plt.rcParams['axes.unicode_minus'] = False
warnings.filterwarnings(action='ignore')

os.chdir('/Users/hankiho/Downloads/weather-master/유통&소셜 데이터')

# %%
weather = pd.read_csv("weather.csv", encoding ='CP949', parse_dates=['date.wt'])
gs = pd.read_csv("gs.csv", encoding ='CP949', parse_dates=['date.gs'])
gs_seoul = gs[gs['reg_01.gs']=='서울특별시']

# %%
name = pd.Series(['과자','라면','마스크','맥주','면도기','생리대','생수','숙취해소제','스타킹','아이스크림','우산','탄산음료'])

plt.rcParams["figure.figsize"] = (30,15)
plt.figure()
gs_seoul_count = gs_seoul.groupby(['qty.gs','cat.gs'])['cat.gs'].count().unstack().reset_index().fillna(0)
for i in range(1,13):
    plt.subplot(3,4,i)
    plt.title(name[i-1])
    #plt.text(250,10000,'왜도: ')
    #plt.text(250,8500,'첨도: ')
    #plt.text(300,10000, gs_seoul_count_skew.iloc[i,1])
    #plt.text(300,8500, gs_seoul_count_kurt.iloc[i,1])
    value=gs_seoul_count.iloc[:,i]
    plt.plot(value)

# %%
seoul_date_cat=gs_seoul.groupby(['date.gs','cat.gs']).sum().reset_index()

plt.rcParams["figure.figsize"] = (20,10)
plt.figure()
cat=seoul_date_cat['cat.gs'].unique().tolist()
for i in range(1,13):
    plt.subplot(3, 4, i)
    plt.title(cat[i-1])
    plt.boxplot(seoul_date_cat[seoul_date_cat['cat.gs']==cat[i-1]]['qty.gs'],vert=0)

# %%
from sklearn.ensemble import IsolationForest
clf = IsolationForest(random_state=1)

def data(x):
    clf.fit(x['qty.gs'].values.reshape(-1,1))
    x['predict'] = clf.predict(x['qty.gs'].values.reshape(-1,1))

# %%
is_0 = gs_seoul['cat.gs']=='과자'
is_1 = gs_seoul['cat.gs']=='라면'
is_2 = gs_seoul['cat.gs']=='마스크'
is_3 = gs_seoul['cat.gs']=='맥주'
is_4 = gs_seoul['cat.gs']=='면도기'
is_5 = gs_seoul['cat.gs']=='생리대'
is_6 = gs_seoul['cat.gs']=='생수'
is_7 = gs_seoul['cat.gs']=='숙취해소제'
is_8 = gs_seoul['cat.gs']=='스타킹'
is_9 = gs_seoul['cat.gs']=='아이스크림'
is_10 = gs_seoul['cat.gs']=='우산'
is_11 = gs_seoul['cat.gs']=='탄산음료'
a = gs_seoul[is_0]
b = gs_seoul[is_1]
c = gs_seoul[is_2]
d = gs_seoul[is_3]
e = gs_seoul[is_4]
f = gs_seoul[is_5]
g = gs_seoul[is_6]
h = gs_seoul[is_7]
i = gs_seoul[is_8]
j = gs_seoul[is_9]
k = gs_seoul[is_10]
l = gs_seoul[is_11]

# %%
data(a)
a['qty.gs'] = a['qty.gs'].apply(lambda x :550 if x>550 else x)
data(b)
b['qty.gs'] = b['qty.gs'].apply(lambda x :359 if x>359 else x)
data(c)
c['qty.gs'] = c['qty.gs'].apply(lambda x :35 if x>35 else x)
data(d)
d['qty.gs'] = d['qty.gs'].apply(lambda x :204 if x >204 else x)
data(e)
e['qty.gs'] = e['qty.gs'].apply(lambda x :28 if x> 28 else x)
data(f)
f['qty.gs'] = f['qty.gs'].apply(lambda x :70 if x>70 else x)
data(g)
g['qty.gs'] = g['qty.gs'].apply(lambda x :190 if x>190 else x)
data(h)
h['qty.gs'] = h['qty.gs'].apply(lambda x :85 if x>85 else x)
data(i)
i['qty.gs'] = i['qty.gs'].apply(lambda x :56 if x>56 else x)
data(j)
j['qty.gs'] = j['qty.gs'].apply(lambda x :336 if x>336 else x)
data(k)
k['qty.gs'] = k['qty.gs'].apply(lambda x :92 if x>92 else x)
data(l)
l['qty.gs'] = l['qty.gs'].apply(lambda x :113 if x>113 else x)
# Out:
# /Users/hankiho/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# /Users/hankiho/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# /Users/hankiho/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# /Users/hankiho/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# ...

# %%
ab = a.append(b)
abc = ab.append(c)
abcd = abc.append(d)
abcde = abcd.append(e)
abcdef = abcde.append(f)
abcdefg = abcdef.append(g)
abcdefgh = abcdefg.append(h)
abcdefghi = abcdefgh.append(i)
abcdefghij = abcdefghi.append(j)
abcdefghijk = abcdefghij.append(k)
abcdefghjkl = abcdefghijk.append(l)
gs_seoul_outlier = abcdefghjkl

# %%
# 아웃라이어가 제거
gs_seoul = gs_seoul_outlier[gs_seoul_outlier['predict'] == 1]

# %%
# 아웃라이너 제거 후
name = pd.Series(['과자','라면','마스크','맥주','면도기','생리대','생수','숙취해소제','스타킹','아이스크림','우산','탄산음료'])

plt.rcParams["figure.figsize"] = (30,15)
plt.figure()
gs_seoul_count = gs_seoul.groupby(['qty.gs','cat.gs'])['cat.gs'].count().unstack().reset_index().fillna(0)
for i in range(1,13):
    plt.subplot(3,4,i)
    plt.title(name[i-1])
    #plt.text(250,10000,'왜도: ')
    #plt.text(250,8500,'첨도: ')
    #plt.text(300,10000, gs_seoul_count_skew.iloc[i,1])
    #plt.text(300,8500, gs_seoul_count_kurt.iloc[i,1])
    value=gs_seoul_count.iloc[:,i]
    plt.plot(value)

# %%
# 아웃라이너 제거 후
seoul_date_cat=gs_seoul.groupby(['date.gs','cat.gs']).sum().reset_index()

plt.rcParams["figure.figsize"] = (20,10)
plt.figure()
cat=seoul_date_cat['cat.gs'].unique().tolist()
for i in range(1,13):
    plt.subplot(3, 4, i)
    plt.title(cat[i-1])
    plt.boxplot(seoul_date_cat[seoul_date_cat['cat.gs']==cat[i-1]]['qty.gs'],vert=0)

# %%
# 아웃라이너 제거 후
seoul_date_cat=gs_seoul.groupby(['date.gs','cat.gs']).sum()
seoul_date_cat1=seoul_date_cat.reset_index()
seoul_date_cat2=seoul_date_cat1.copy()
seoul_date_cat2=seoul_date_cat2.set_index(['date.gs','cat.gs'])['qty.gs'].unstack()
seoul_date_cat3=seoul_date_cat2.reset_index()

plt.rcParams["figure.figsize"] = (20,10)
plt.rcParams['lines.linewidth'] = 0.5
plt.figure()
cat=seoul_date_cat1['cat.gs'].unique().tolist()
for i in range(1,13):
    plt.subplot(2, 6, i)
    plt.title(cat[i-1])
    plt.plot(seoul_date_cat3['date.gs'],seoul_date_cat3.iloc[:,i])

# %%
gs_store = pd.read_csv("gs_store.csv")

# %%
# 굳이 그림을 안그리고 편의점 갯수 4분위수로 잘랐다고 ppt에 설명하시면 될거 같습니다.
gs_store['시군구'] = ''
len_ = len(gs_store)
for n in range(len_):
    gs_store['시군구'].values[n] = gs_store['Address'].values[n].split()[1]
gs_count = pd.DataFrame(gs_store['시군구'].value_counts())
gs_count
# Out:
#       시군구
# 강남구   285
# 송파구   171
# 마포구   166
# 영등포구  165
# 강서구   151
# 관악구   143
# 서초구   134
# 은평구   114
# 동작구   112
# 성북구   112
# 동대문구  110
# 노원구   109
# 광진구   108
# 구로구   105
# 중구    101
# 강동구   101
# 중랑구    99
# 서대문구   92
# 양천구    88
# 금천구    84
# 종로구    83
# 용산구    80
# 강북구    76
# 성동구    74
# 도봉구    60

# %%
# 구 합치기
gs_seoul.ix[gs_seoul['reg_02.gs'] == "강남구", "reg_02.gs"] = '4분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "송파구", "reg_02.gs"] = '4분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "마포구", "reg_02.gs"] = '4분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "영등포구", "reg_02.gs"] = '4분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "강서구", "reg_02.gs"] = '4분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "관악구", "reg_02.gs"] = '4분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "서초구", "reg_02.gs"] = '4분위수'

gs_seoul.ix[gs_seoul['reg_02.gs'] == "은평구", "reg_02.gs"] = '3분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "성북구", "reg_02.gs"] = '3분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "동작구", "reg_02.gs"] = '3분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "동대문구", "reg_02.gs"] = '3분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "노원구", "reg_02.gs"] = '3분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "광진구", "reg_02.gs"] = '3분위수'

gs_seoul.ix[gs_seoul['reg_02.gs'] == "구로구", "reg_02.gs"] = '2분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "중구", "reg_02.gs"] = '2분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "강동구", "reg_02.gs"] = '2분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "중랑구", "reg_02.gs"] = '2분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "서대문구", "reg_02.gs"] = '2분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "양천구", "reg_02.gs"] = '2분위수'

# (금천구, 종로구, 용산구, 강북구, 성동구, 도봉구)
gs_seoul.ix[gs_seoul['reg_02.gs'] == "금천구", "reg_02.gs"] = '1분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "종로구", "reg_02.gs"] = '1분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "용산구", "reg_02.gs"] = '1분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "강북구", "reg_02.gs"] = '1분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "성동구", "reg_02.gs"] = '1분위수'
gs_seoul.ix[gs_seoul['reg_02.gs'] == "도봉구", "reg_02.gs"] = '1분위수'

# %%
gs_seoul_outlier = gs_seoul.groupby(['date.gs','reg_02.gs','cat.gs'])['qty.gs'].sum().unstack().reset_index().fillna('0')
gs_seoul_outlier['과자']=gs_seoul_outlier['과자'].astype(float)
gs_seoul_outlier['라면']=gs_seoul_outlier['라면'].astype(float)
gs_seoul_outlier['마스크']=gs_seoul_outlier['마스크'].astype(float)
gs_seoul_outlier['맥주']=gs_seoul_outlier['맥주'].astype(float)
gs_seoul_outlier['면도기']=gs_seoul_outlier['면도기'].astype(float)
gs_seoul_outlier['생리대']=gs_seoul_outlier['생리대'].astype(float)
gs_seoul_outlier['생수']=gs_seoul_outlier['생수'].astype(float)
gs_seoul_outlier['숙취해소제']=gs_seoul_outlier['숙취해소제'].astype(float)
gs_seoul_outlier['스타킹']=gs_seoul_outlier['스타킹'].astype(float)
gs_seoul_outlier['아이스크림']=gs_seoul_outlier['아이스크림'].astype(float)
gs_seoul_outlier['우산']=gs_seoul_outlier['우산'].astype(float)
gs_seoul_outlier['탄산음료']=gs_seoul_outlier['탄산음료'].astype(float)

# %%
# 상품 합치기. ppt에 넣을떄는 EDA할떄 그린 판매량 시계열 데이터 그래프 넣고 설명하기면 될거 같습니다.
gs_seoul_outlier['스테디셀러'] = gs_seoul_outlier['과자']+gs_seoul_outlier['라면']+gs_seoul_outlier['숙취해소제']
gs_seoul_outlier['일회용품'] = gs_seoul_outlier['면도기']+gs_seoul_outlier['생리대']
gs_seoul_outlier['계절성(여름,겨울)'] = gs_seoul_outlier['맥주']+gs_seoul_outlier['아이스크림'] +gs_seoul_outlier['탄산음료']+gs_seoul_outlier['생수']

# %%
gs_seoul_outlier=gs_seoul_outlier.drop(['과자'], axis=1)
gs_seoul_outlier=gs_seoul_outlier.drop(['라면'], axis=1)
gs_seoul_outlier=gs_seoul_outlier.drop(['맥주'], axis=1)
gs_seoul_outlier=gs_seoul_outlier.drop(['면도기'], axis=1)
gs_seoul_outlier=gs_seoul_outlier.drop(['생리대'], axis=1)
gs_seoul_outlier=gs_seoul_outlier.drop(['생수'], axis=1)
gs_seoul_outlier=gs_seoul_outlier.drop(['숙취해소제'], axis=1)
gs_seoul_outlier=gs_seoul_outlier.drop(['아이스크림'], axis=1)
gs_seoul_outlier=gs_seoul_outlier.drop(['우산'], axis=1)
gs_seoul_outlier=gs_seoul_outlier.drop(['탄산음료'], axis=1)

# %%
df = gs_seoul_outlier
df_01 = df[df['reg_02.gs'] == '1분위수']
df_02 = df[df['reg_02.gs'] == '2분위수']
df_03 = df[df['reg_02.gs'] == '3분위수']
df_04 = df[df['reg_02.gs'] == '4분위수']

# %%
# 데이터가 잘 정제됬다는걸 보여주기 위해 시각화함.

# %%
# 1분위
figure, ((ax1,ax2,ax3,ax4,ax5)) = plt.subplots(nrows=1, ncols=5)
figure.set_size_inches(18,8)
graph_num = [ax1, ax2, ax3, ax4, ax5]
    
list_ = ['마스크','스타킹','스테디셀러','일회용품','계절성(여름,겨울)']
len_ = len(list_)
for i in range(len_):
    sns.lineplot(data = df_01, x = 'date.gs', y = list_[i],ax = graph_num[i])

# %%
# 2분위
figure, ((ax1,ax2,ax3,ax4,ax5)) = plt.subplots(nrows=1, ncols=5)
figure.set_size_inches(18,8)
graph_num = [ax1, ax2, ax3, ax4, ax5]
    
list_ = ['마스크','스타킹','스테디셀러','일회용품','계절성(여름,겨울)']
len_ = len(list_)
for i in range(len_):
    sns.lineplot(data = df_02, x = 'date.gs', y = list_[i],ax = graph_num[i])

# %%
# 3분위
figure, ((ax1,ax2,ax3,ax4,ax5)) = plt.subplots(nrows=1, ncols=5)
figure.set_size_inches(18,8)
graph_num = [ax1, ax2, ax3, ax4, ax5]
    
list_ = ['마스크','스타킹','스테디셀러','일회용품','계절성(여름,겨울)']
len_ = len(list_)
for i in range(len_):
    sns.lineplot(data = df_03, x = 'date.gs', y = list_[i],ax = graph_num[i])

# %%
# 3분위
figure, ((ax1,ax2,ax3,ax4,ax5)) = plt.subplots(nrows=1, ncols=5)
figure.set_size_inches(18,8)
graph_num = [ax1, ax2, ax3, ax4, ax5]
    
list_ = ['마스크','스타킹','스테디셀러','일회용품','계절성(여름,겨울)']
len_ = len(list_)
for i in range(len_):
    sns.lineplot(data = df_04, x = 'date.gs', y = list_[i],ax = graph_num[i])

# %%
# 데이터 저장
df.to_csv('/Users/hankiho/Desktop/gs_seoul.csv', index = False, encoding = "utf-8-sig")
